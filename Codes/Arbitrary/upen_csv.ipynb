# %%
import pandas as pd

# %%
df= pd.read_csv('UPENN-GBM_clinical_info_v1.1.csv')
df
# Out:
#                      ID Gender  Age_at_scan_years Survival_from_surgery_days  \
# 0    UPENN-GBM-00001_11      F              52.16              Not Available
# 1    UPENN-GBM-00002_11      F              61.30                        291
# 2    UPENN-GBM-00003_11      M              42.82              Not Available
# 3    UPENN-GBM-00004_11      M              33.43              Not Available
# 4    UPENN-GBM-00005_11      M              53.33              Not Available
# ..                  ...    ...                ...                        ...
# 666  UPENN-GBM-00626_21      F              57.19              Not Available
# 667  UPENN-GBM-00627_21      F              57.40              Not Available
# 668  UPENN-GBM-00628_21      M              55.09              Not Available
# 669  UPENN-GBM-00629_21      M              71.44              Not Available
# 670  UPENN-GBM-00630_21      M              65.47              Not Available
#
# ...

# %%
len(df)
# Out:
# 671

# %%
df.MGMT.unique()
# Out:
# array(['Not Available', 'Unmethylated', 'Indeterminate', 'Methylated'],
#       dtype=object)

# %%
df1 = pd.DataFrame({
    "id":[],
    "idh1":[],
    "mgmt":[]
})
df1
# Out:
# Empty DataFrame
# Columns: [id, idh1, mgmt]
# Index: []

# %%
count = 0
for i in range(len(df)):
   
    if df.IDH1[i] == 'Wildtype' and (df.MGMT[i] == 'Unmethylated' or df.MGMT[i] == 'Methylated'):
        count+=1
        l=0
        
        if df.MGMT[i] == 'Unmethylated':
            pass
        else:
            l=1
        print(df.IDH1[i], df.ID[i])
        df2 = pd.DataFrame({'id': [df.ID[i]], 'idh1': [df.IDH1[i]],
                           'mgmt': [l] })
        df1= df1.append(df2)
df1
# Out:
# Wildtype UPENN-GBM-00022_11
# Wildtype UPENN-GBM-00034_11
# Wildtype UPENN-GBM-00088_11
# Wildtype UPENN-GBM-00091_11
# Wildtype UPENN-GBM-00092_11
# Wildtype UPENN-GBM-00093_11
# Wildtype UPENN-GBM-00093_21
# Wildtype UPENN-GBM-00094_11
# Wildtype UPENN-GBM-00095_11
# Wildtype UPENN-GBM-00098_11
# Wildtype UPENN-GBM-00115_11
# Wildtype UPENN-GBM-00117_11
# Wildtype UPENN-GBM-00120_11
# Wildtype UPENN-GBM-00121_11
# Wildtype UPENN-GBM-00122_11
# Wildtype UPENN-GBM-00122_21
# Wildtype UPENN-GBM-00124_11
# Wildtype UPENN-GBM-00125_11
# Wildtype UPENN-GBM-00128_11
# Wildtype UPENN-GBM-00128_21
# Wildtype UPENN-GBM-00129_11
# Wildtype UPENN-GBM-00130_21
# Wildtype UPENN-GBM-00131_11
# Wildtype UPENN-GBM-00132_11
# Wildtype UPENN-GBM-00133_11
# Wildtype UPENN-GBM-00134_11
# Wildtype UPENN-GBM-00134_21
# Wildtype UPENN-GBM-00135_11
# Wildtype UPENN-GBM-00136_11
# Wildtype UPENN-GBM-00138_11
# Wildtype UPENN-GBM-00139_11
# Wildtype UPENN-GBM-00140_11
# Wildtype UPENN-GBM-00140_21
# ...

# %%
print(df.ID[0])
# Out:
# UPENN-GBM-00001_11

# %%
df1.to_csv('upen_patient.csv')
